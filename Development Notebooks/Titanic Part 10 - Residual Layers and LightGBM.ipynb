# %% [markdown]
# # Titanic Survival Classification - Residual Layers and LightGBM (Part 10)
#
# The primary focus of this notebook will be to build and test the effectiveness of using residual blocks for skip-connections to train very deep dense networks, in the same fashion convolutional blocks are used  - potentially with the same sparsity constraints.
#
# Once this has been tested the next step will be to have a look at the functionality and performance of the LightGBM package.

# %%
##### First importing some relevant packages
import numpy as np
import pandas as pd

#Stop pandas from truncating output view
pd.options.display.max_columns = None

#Import Tensorflow
import tensorflow as tf

#Import Keras
from keras import layers
from keras.layers import Input, Dense, Activation, BatchNormalization, Dropout, Reshape, Flatten, Add
from keras.layers.advanced_activations import LeakyReLU, PReLU
from keras.models import Sequential, Model
from keras import regularizers
from keras.optimizers import Adam, SGD

#Import mathematical functions
from random import *
import math
import matplotlib
import matplotlib.pyplot as plt

#Get regular expression package
import re

#Import  Scikit learn framework
import sklearn as sk
from sklearn import svm
from sklearn import linear_model
from sklearn.metrics import roc_auc_score, roc_curve
# Out:
# F:\anaconda\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#Import the functions built in previous parts
from Titanic_Import import *

full_set = pd.read_csv('D:/Datasets/Titanic/train.csv')
sub_set = pd.read_csv('D:/Datasets/Titanic/test.csv')

# %%
append_set = full_set
append_set = append_set.append([sub_set], ignore_index =True )
clean_set = Cleanse_Data_v3(append_set)
X_Train, Y_Train, X_CV, Y_CV, X_Test = dataset_splitter(clean_set, cv_size = 200)

# %% [markdown]
# ## Residual Dense Network
#
# So to start testing something I have personally been curious about - how effective are residual layers in dense networks.
#
# We know that they are extremely effective in convolutional networks and allow them to become significantly deeper by avoiding the issues of gradient vanishing/explosion by allowing layers to easily avoid learning the identity function.  So do they have the same effect in regular networks?  Or does the nature of the convolutional operator mean that this is a solution unique to convolutional networks?
#
# Given how dense networks don't typically have any residual layers it is reasonable to assume that there's an inherant flaw with this design philosophy, however I wish to satisfy my curiosity nonetheless.
#
# So following the insights of standard convolutional approaches, the logic entails a network structure of residual blocks of the N of units per block with each block having L layers and skip connections from start to end.  We can also draw on the insights of DenseNet (https://arxiv.org/abs/1802.08797) to connect every layer in each residual block to every other layer.  Then we will need a non-linear activation and likely a single dense layer to shrink the size for the next residual block.
#
# This single layer to shrink the size of the output to U units where U < N is intuitively the reason for residual blocks not being applied to traditional dense networks.  This is due to the orthogonal nature of each node in dense networks by comparison to the locality and spacial distances being a factor in convolutional networks.
#
# Initial ideas for getting around this issue are having a single layer cutoff of the density.  Most other forms of dimensionality reduction (such as autoencoders or PCA) won't work due to difficulty/impossibility of training or irreversability of the operation.
#
# Perhaps there is a form of dimensionality reduction I have not considered but to keep it simple I will simply use a single dense layer, although I expect the pooling layer has a crucial role in the viability of residual blocks.
#
# I will experiment with 2 architectures - one with 1 skip connection between the first and last layer per block, and the other another with every layer of a residual block connected with every previous layer.

# %%
def ResBlock_v1(X, layers, units, act_reg = None, ker_reg = None):

    #Single Layer to reduce dimensionality
    X = Dense(units, activation='relu', activity_regularizer = act_reg, kernel_regularizer = ker_reg)(X)
    
    #Batch normalize input as it will be added at end
    X = BatchNormalization()(X)

    #Snapshot first layer to skip to end
    X_shortcut = X
    
    for i in range(layers):
        X = Dense(units, activation='relu', activity_regularizer = act_reg, kernel_regularizer = ker_reg)(X)
        
    #Batch norm last layer
    X = BatchNormalization()(X)
    
    #Add skip connection
    X = Add()([X, X_shortcut])
    #Apply non-linearity
    X = Activation('relu')(X)

    return X

# %%
def Build_Resnet(input_shape, layers, act_reg = None, ker_reg = None):
    X_input = Input(input_shape)
    
    num_layers = len(layers)
    
    for i in range(num_layers):
        if i == 0 :
            X = ResBlock_v1(X_input, res_layers[i][1], res_layers[i][0], act_reg = act_reg, ker_reg = ker_reg)
        else :
            X = ResBlock_v1(X, res_layers[i][1], res_layers[i][0], act_reg = act_reg, ker_reg = ker_reg)
   
    #Build output layer
    X = Dense(1, activation='sigmoid')(X)
    
    model = Model(inputs = X_input, outputs = X, name='Residual_model')
    
    return model

# %% [markdown]
# Now the building blocks are established lets try it out.

# %%
res_layers = {0: (25, 1), 1: (20, 3), 2: (10, 3), 3: (5, 5), 5: (3, 5)}

# %%
test_model = Build_Resnet((X_Train.shape[1], ), res_layers, regularizers.l2(0.01), None)
test_model.compile(optimizer = "Adam", loss = "binary_crossentropy", metrics = ["accuracy", K_F1_score])
test_model.fit(x = X_Train, y = Y_Train, epochs = 256, verbose = 1)
# Out:
# Epoch 1/256
# 691/691 [==============================] - 4s 5ms/step - loss: 34.5472 - acc: 0.4211 - K_F1_score: 0.5148
# Epoch 2/256
# 691/691 [==============================] - 1s 1ms/step - loss: 28.7633 - acc: 0.4573 - K_F1_score: 0.4910
# Epoch 3/256
# 691/691 [==============================] - 1s 1ms/step - loss: 24.8304 - acc: 0.5369 - K_F1_score: 0.4808
# Epoch 4/256
# 691/691 [==============================] - 1s 2ms/step - loss: 22.2812 - acc: 0.5991 - K_F1_score: 0.4218
# Epoch 5/256
# 691/691 [==============================] - 1s 1ms/step - loss: 20.2637 - acc: 0.5962 - K_F1_score: 0.4283
# Epoch 6/256
# 691/691 [==============================] - 1s 1ms/step - loss: 18.9302 - acc: 0.5904 - K_F1_score: 0.3960
# Epoch 7/256
# 691/691 [==============================] - 1s 1ms/step - loss: 18.0735 - acc: 0.5789 - K_F1_score: 0.4230
# Epoch 8/256
# 691/691 [==============================] - 1s 1ms/step - loss: 17.2019 - acc: 0.5687 - K_F1_score: 0.3955
# Epoch 9/256
# 691/691 [==============================] - 1s 1ms/step - loss: 16.6953 - acc: 0.5832 - K_F1_score: 0.3959
# Epoch 10/256
# 691/691 [==============================] - 1s 1ms/step - loss: 15.9641 - acc: 0.5716 - K_F1_score: 0.3783
# Epoch 11/256
# 691/691 [==============================] - 1s 1ms/step - loss: 15.0338 - acc: 0.5876 - K_F1_score: 0.3814A: 0s - loss: 15.9002 - acc: 0.6250 - K_F1_sco
# Epoch 12/256
# 691/691 [==============================] - 1s 1ms/step - loss: 14.5314 - acc: 0.5876 - K_F1_score: 0.3781
# Epoch 13/256
# 691/691 [==============================] - 1s 1ms/step - loss: 13.9982 - acc: 0.6122 - K_F1_score: 0.3777
# Epoch 14/256
# 691/691 [==============================] - 1s 1ms/step - loss: 13.3504 - acc: 0.5861 - K_F1_score: 0.3676
# Epoch 15/256
# 691/691 [==============================] - 1s 1ms/step - loss: 12.7221 - acc: 0.5702 - K_F1_score: 0.3557
# Epoch 16/256
# 691/691 [==============================] - 1s 1ms/step - loss: 12.2556 - acc: 0.5919 - K_F1_score: 0.3591
# Epoch 17/256
# 691/691 [==============================] - 1s 1ms/step - loss: 11.7058 - acc: 0.5977 - K_F1_score: 0.3610
# Epoch 18/256
# 691/691 [==============================] - 1s 1ms/step - loss: 11.5578 - acc: 0.5876 - K_F1_score: 0.3529
# Epoch 19/256
# 691/691 [==============================] - 1s 1ms/step - loss: 11.1759 - acc: 0.5948 - K_F1_score: 0.3542
# Epoch 20/256
# 691/691 [==============================] - 1s 2ms/step - loss: 10.7940 - acc: 0.5933 - K_F1_score: 0.3539
# Epoch 21/256
# 691/691 [==============================] - 1s 1ms/step - loss: 10.5268 - acc: 0.6064 - K_F1_score: 0.3530
# Epoch 22/256
# 691/691 [==============================] - 1s 1ms/step - loss: 10.2263 - acc: 0.5948 - K_F1_score: 0.3501
# Epoch 23/256
# 691/691 [==============================] - 1s 1ms/step - loss: 9.8860 - acc: 0.5948 - K_F1_score: 0.3494
# Epoch 24/256
# 691/691 [==============================] - 1s 1ms/step - loss: 9.5766 - acc: 0.6049 - K_F1_score: 0.3492
# Epoch 25/256
# 691/691 [==============================] - 1s 1ms/step - loss: 9.4067 - acc: 0.6035 - K_F1_score: 0.3448
# Epoch 26/256
# 691/691 [==============================] - 1s 1ms/step - loss: 9.3333 - acc: 0.5991 - K_F1_score: 0.3412
# Epoch 27/256
# 691/691 [==============================] - 1s 1ms/step - loss: 9.0075 - acc: 0.6020 - K_F1_score: 0.3421
# Epoch 28/256
# 691/691 [==============================] - 1s 1ms/step - loss: 8.7466 - acc: 0.6078 - K_F1_score: 0.3478
# Epoch 29/256
# 691/691 [==============================] - 1s 1ms/step - loss: 8.5799 - acc: 0.6035 - K_F1_score: 0.3475
# Epoch 30/256
# 691/691 [==============================] - 1s 1ms/step - loss: 8.3382 - acc: 0.6049 - K_F1_score: 0.3487
# Epoch 31/256
# 691/691 [==============================] - 1s 1ms/step - loss: 8.3132 - acc: 0.5991 - K_F1_score: 0.3454
# Epoch 32/256
# 691/691 [==============================] - 1s 1ms/step - loss: 8.1389 - acc: 0.6093 - K_F1_score: 0.3433
# Epoch 33/256
# 691/691 [==============================] - 1s 1ms/step - loss: 7.8900 - acc: 0.6078 - K_F1_score: 0.3455
# Epoch 34/256
# 691/691 [==============================] - 1s 1ms/step - loss: 7.5862 - acc: 0.6078 - K_F1_score: 0.3453
# Epoch 35/256
# 691/691 [==============================] - 1s 1ms/step - loss: 7.3638 - acc: 0.5977 - K_F1_score: 0.3414
# Epoch 36/256
# 691/691 [==============================] - 1s 1ms/step - loss: 7.2815 - acc: 0.5991 - K_F1_score: 0.3381
# Epoch 37/256
# 691/691 [==============================] - 1s 1ms/step - loss: 7.1273 - acc: 0.6035 - K_F1_score: 0.3403
# Epoch 38/256
# 691/691 [==============================] - 1s 1ms/step - loss: 7.0770 - acc: 0.6064 - K_F1_score: 0.3425
# Epoch 39/256
# 691/691 [==============================] - 1s 1ms/step - loss: 6.8957 - acc: 0.5991 - K_F1_score: 0.3361
# Epoch 40/256
# 691/691 [==============================] - 1s 1ms/step - loss: 6.6960 - acc: 0.6020 - K_F1_score: 0.3386
# Epoch 41/256
# 691/691 [==============================] - 1s 1ms/step - loss: 6.5381 - acc: 0.5962 - K_F1_score: 0.3361
# Epoch 42/256
# 691/691 [==============================] - 1s 1ms/step - loss: 6.4531 - acc: 0.5991 - K_F1_score: 0.3359
# Epoch 43/256
# 691/691 [==============================] - 1s 1ms/step - loss: 6.3343 - acc: 0.6035 - K_F1_score: 0.3393
# Epoch 44/256
# 691/691 [==============================] - 1s 1ms/step - loss: 6.1506 - acc: 0.6020 - K_F1_score: 0.3356
# Epoch 45/256
# 691/691 [==============================] - 1s 1ms/step - loss: 5.9671 - acc: 0.6006 - K_F1_score: 0.3368
# Epoch 46/256
# 691/691 [==============================] - 1s 1ms/step - loss: 5.8025 - acc: 0.6006 - K_F1_score: 0.3371
# Epoch 47/256
# 691/691 [==============================] - 1s 1ms/step - loss: 5.9547 - acc: 0.5991 - K_F1_score: 0.3357
# Epoch 48/256
# 691/691 [==============================] - 1s 1ms/step - loss: 5.8480 - acc: 0.5919 - K_F1_score: 0.3322
# Epoch 49/256
# 691/691 [==============================] - 1s 1ms/step - loss: 5.6241 - acc: 0.5991 - K_F1_score: 0.3311
# Epoch 50/256
# 691/691 [==============================] - 1s 2ms/step - loss: 5.4885 - acc: 0.6006 - K_F1_score: 0.3338
# Epoch 51/256
# 691/691 [==============================] - 1s 2ms/step - loss: 5.3680 - acc: 0.5962 - K_F1_score: 0.3324
# Epoch 52/256
# 691/691 [==============================] - 1s 2ms/step - loss: 5.3000 - acc: 0.5991 - K_F1_score: 0.3314
# Epoch 53/256
# 691/691 [==============================] - 1s 1ms/step - loss: 5.1462 - acc: 0.6006 - K_F1_score: 0.3341
# Epoch 54/256
# 691/691 [==============================] - 1s 1ms/step - loss: 5.0101 - acc: 0.6006 - K_F1_score: 0.3327
# Epoch 55/256
# 691/691 [==============================] - 1s 1ms/step - loss: 4.9443 - acc: 0.5977 - K_F1_score: 0.3303
# Epoch 56/256
# 691/691 [==============================] - 1s 1ms/step - loss: 4.8221 - acc: 0.5991 - K_F1_score: 0.3306
# Epoch 57/256
# 691/691 [==============================] - 1s 1ms/step - loss: 4.6005 - acc: 0.5991 - K_F1_score: 0.3301
# Epoch 58/256
# 691/691 [==============================] - 1s 1ms/step - loss: 4.5438 - acc: 0.5977 - K_F1_score: 0.3292
# Epoch 59/256
# 691/691 [==============================] - 1s 1ms/step - loss: 4.4904 - acc: 0.5977 - K_F1_score: 0.3289
# Epoch 60/256
# 691/691 [==============================] - 1s 1ms/step - loss: 4.3860 - acc: 0.5977 - K_F1_score: 0.3300
# Epoch 61/256
# 691/691 [==============================] - 1s 1ms/step - loss: 4.2425 - acc: 0.5991 - K_F1_score: 0.3295
# Epoch 62/256
# 691/691 [==============================] - 1s 1ms/step - loss: 4.2661 - acc: 0.5991 - K_F1_score: 0.3321
# Epoch 63/256
# 691/691 [==============================] - 1s 1ms/step - loss: 4.1003 - acc: 0.5977 - K_F1_score: 0.3264
# Epoch 64/256
# 691/691 [==============================] - 1s 1ms/step - loss: 4.0590 - acc: 0.5991 - K_F1_score: 0.3316
# Epoch 65/256
# 691/691 [==============================] - 1s 1ms/step - loss: 3.9495 - acc: 0.5991 - K_F1_score: 0.3292
# Epoch 66/256
# 691/691 [==============================] - 1s 1ms/step - loss: 3.9414 - acc: 0.5977 - K_F1_score: 0.3279
# Epoch 67/256
# 691/691 [==============================] - 1s 1ms/step - loss: 3.8765 - acc: 0.6006 - K_F1_score: 0.3318
# Epoch 68/256
# 691/691 [==============================] - 1s 1ms/step - loss: 3.7613 - acc: 0.5991 - K_F1_score: 0.3310
# Epoch 69/256
# 691/691 [==============================] - 1s 1ms/step - loss: 3.6356 - acc: 0.5991 - K_F1_score: 0.3295
# Epoch 70/256
# 691/691 [==============================] - 1s 1ms/step - loss: 3.6252 - acc: 0.5991 - K_F1_score: 0.3304
# Epoch 71/256
# 691/691 [==============================] - 1s 1ms/step - loss: 3.4821 - acc: 0.5991 - K_F1_score: 0.3295: 0s - loss: 3.5986 - acc: 0.6278 - K_F1_s
# Epoch 72/256
# 691/691 [==============================] - 1s 1ms/step - loss: 3.4203 - acc: 0.5991 - K_F1_score: 0.3257
# Epoch 73/256
# 691/691 [==============================] - 1s 1ms/step - loss: 3.3546 - acc: 0.5991 - K_F1_score: 0.3309
# Epoch 74/256
# 691/691 [==============================] - 1s 1ms/step - loss: 3.2977 - acc: 0.5991 - K_F1_score: 0.3286
# Epoch 75/256
# 691/691 [==============================] - 1s 1ms/step - loss: 3.2870 - acc: 0.5991 - K_F1_score: 0.3319
# Epoch 76/256
# 691/691 [==============================] - 1s 1ms/step - loss: 3.2211 - acc: 0.5991 - K_F1_score: 0.3310
# Epoch 77/256
# 691/691 [==============================] - 1s 1ms/step - loss: 3.1533 - acc: 0.5991 - K_F1_score: 0.3305
# Epoch 78/256
# 691/691 [==============================] - 1s 1ms/step - loss: 3.1564 - acc: 0.5991 - K_F1_score: 0.3314
# Epoch 79/256
# 691/691 [==============================] - 1s 1ms/step - loss: 3.1290 - acc: 0.5991 - K_F1_score: 0.3319
# Epoch 80/256
# 691/691 [==============================] - 1s 1ms/step - loss: 3.0288 - acc: 0.5991 - K_F1_score: 0.3309
# Epoch 81/256
# 691/691 [==============================] - 1s 1ms/step - loss: 2.9799 - acc: 0.5991 - K_F1_score: 0.3321
# Epoch 82/256
# 691/691 [==============================] - 1s 1ms/step - loss: 2.8579 - acc: 0.5991 - K_F1_score: 0.3307
# Epoch 83/256
# 691/691 [==============================] - 1s 2ms/step - loss: 2.8327 - acc: 0.5991 - K_F1_score: 0.3280
# Epoch 84/256
# 691/691 [==============================] - 1s 1ms/step - loss: 2.7285 - acc: 0.5991 - K_F1_score: 0.3299
# Epoch 85/256
# 691/691 [==============================] - 1s 1ms/step - loss: 2.7248 - acc: 0.5991 - K_F1_score: 0.3303
# Epoch 86/256
# 691/691 [==============================] - 1s 1ms/step - loss: 2.7210 - acc: 0.5991 - K_F1_score: 0.3306
# Epoch 87/256
# 691/691 [==============================] - 1s 1ms/step - loss: 2.6401 - acc: 0.5991 - K_F1_score: 0.3310
# Epoch 88/256
# 691/691 [==============================] - 1s 1ms/step - loss: 2.5915 - acc: 0.5991 - K_F1_score: 0.3302
# Epoch 89/256
# 691/691 [==============================] - 1s 1ms/step - loss: 2.6209 - acc: 0.5977 - K_F1_score: 0.3293
# Epoch 90/256
# 691/691 [==============================] - 1s 2ms/step - loss: 2.5843 - acc: 0.5991 - K_F1_score: 0.3305
# Epoch 91/256
# 691/691 [==============================] - 1s 1ms/step - loss: 2.5053 - acc: 0.5991 - K_F1_score: 0.3302
# Epoch 92/256
# 691/691 [==============================] - 1s 1ms/step - loss: 2.4945 - acc: 0.5991 - K_F1_score: 0.3308: 0s - loss: 2.5988 - acc: 0.5
# Epoch 93/256
# 691/691 [==============================] - 1s 1ms/step - loss: 2.4677 - acc: 0.5991 - K_F1_score: 0.3310
# Epoch 94/256
# 691/691 [==============================] - 1s 2ms/step - loss: 2.4092 - acc: 0.5991 - K_F1_score: 0.3292
# Epoch 95/256
# 691/691 [==============================] - 1s 1ms/step - loss: 2.3835 - acc: 0.5991 - K_F1_score: 0.3281
# Epoch 96/256
# 691/691 [==============================] - 1s 2ms/step - loss: 2.2662 - acc: 0.5991 - K_F1_score: 0.3301
# Epoch 97/256
# 691/691 [==============================] - 1s 2ms/step - loss: 2.2697 - acc: 0.5991 - K_F1_score: 0.3302
# Epoch 98/256
# 691/691 [==============================] - 1s 1ms/step - loss: 2.2520 - acc: 0.5991 - K_F1_score: 0.3266
# Epoch 99/256
# 691/691 [==============================] - 1s 2ms/step - loss: 2.2454 - acc: 0.5991 - K_F1_score: 0.3304
# Epoch 100/256
# 691/691 [==============================] - 1s 2ms/step - loss: 2.2096 - acc: 0.5991 - K_F1_score: 0.3292
# Epoch 101/256
# 691/691 [==============================] - 1s 2ms/step - loss: 2.1657 - acc: 0.5991 - K_F1_score: 0.3301
# Epoch 102/256
# 691/691 [==============================] - 1s 2ms/step - loss: 2.1748 - acc: 0.5991 - K_F1_score: 0.3289
# Epoch 103/256
# 691/691 [==============================] - 1s 2ms/step - loss: 2.1554 - acc: 0.5991 - K_F1_score: 0.3293
# Epoch 104/256
# 691/691 [==============================] - 1s 1ms/step - loss: 2.1072 - acc: 0.5991 - K_F1_score: 0.3287
# Epoch 105/256
# 691/691 [==============================] - 1s 1ms/step - loss: 2.0927 - acc: 0.5991 - K_F1_score: 0.3302
# Epoch 106/256
# 691/691 [==============================] - 1s 1ms/step - loss: 2.0604 - acc: 0.5991 - K_F1_score: 0.3309
# Epoch 107/256
# 691/691 [==============================] - 1s 1ms/step - loss: 2.0340 - acc: 0.5991 - K_F1_score: 0.3312
# Epoch 108/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.9577 - acc: 0.5991 - K_F1_score: 0.3298
# Epoch 109/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.9603 - acc: 0.5991 - K_F1_score: 0.3317
# Epoch 110/256
# 691/691 [==============================] - 1s 2ms/step - loss: 1.8994 - acc: 0.5991 - K_F1_score: 0.3289
# Epoch 111/256
# 691/691 [==============================] - 1s 2ms/step - loss: 1.9024 - acc: 0.5991 - K_F1_score: 0.3305
# Epoch 112/256
# 691/691 [==============================] - 1s 2ms/step - loss: 1.8697 - acc: 0.5991 - K_F1_score: 0.3300
# Epoch 113/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.8704 - acc: 0.5991 - K_F1_score: 0.3303
# Epoch 114/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.8190 - acc: 0.5991 - K_F1_score: 0.3309
# Epoch 115/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.8064 - acc: 0.5991 - K_F1_score: 0.3298
# Epoch 116/256
# 691/691 [==============================] - 1s 2ms/step - loss: 1.7393 - acc: 0.5991 - K_F1_score: 0.3306
# Epoch 117/256
# 691/691 [==============================] - 1s 2ms/step - loss: 1.7411 - acc: 0.5991 - K_F1_score: 0.3311
# Epoch 118/256
# 691/691 [==============================] - 1s 2ms/step - loss: 1.6879 - acc: 0.5991 - K_F1_score: 0.3305
# Epoch 119/256
# 691/691 [==============================] - 1s 2ms/step - loss: 1.6817 - acc: 0.5991 - K_F1_score: 0.3314
# Epoch 120/256
# 691/691 [==============================] - 1s 2ms/step - loss: 1.6857 - acc: 0.5991 - K_F1_score: 0.3298
# Epoch 121/256
# 691/691 [==============================] - 1s 2ms/step - loss: 1.6557 - acc: 0.5991 - K_F1_score: 0.3306
# Epoch 122/256
# 691/691 [==============================] - 1s 2ms/step - loss: 1.6440 - acc: 0.5991 - K_F1_score: 0.3279
# Epoch 123/256
# 691/691 [==============================] - 1s 2ms/step - loss: 1.7203 - acc: 0.5991 - K_F1_score: 0.3318
# Epoch 124/256
# 691/691 [==============================] - 1s 2ms/step - loss: 1.8016 - acc: 0.5991 - K_F1_score: 0.3304
# Epoch 125/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.7751 - acc: 0.5991 - K_F1_score: 0.3315: 0s - loss: 1.7435 - acc: 0.6250
# Epoch 126/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.7646 - acc: 0.5991 - K_F1_score: 0.3301
# Epoch 127/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.7258 - acc: 0.5991 - K_F1_score: 0.3306
# Epoch 128/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.6795 - acc: 0.5991 - K_F1_score: 0.3315
# Epoch 129/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.6677 - acc: 0.5991 - K_F1_score: 0.3306
# Epoch 130/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.6379 - acc: 0.5991 - K_F1_score: 0.3289
# Epoch 131/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.6296 - acc: 0.5991 - K_F1_score: 0.3304
# Epoch 132/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.5835 - acc: 0.5991 - K_F1_score: 0.3307
# Epoch 133/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.5729 - acc: 0.5991 - K_F1_score: 0.3314
# Epoch 134/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.5339 - acc: 0.5991 - K_F1_score: 0.3304
# Epoch 135/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.4880 - acc: 0.5991 - K_F1_score: 0.3304
# Epoch 136/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.4954 - acc: 0.5991 - K_F1_score: 0.3286
# Epoch 137/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.4835 - acc: 0.5991 - K_F1_score: 0.3313
# Epoch 138/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.4774 - acc: 0.5991 - K_F1_score: 0.3299
# Epoch 139/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.4351 - acc: 0.5991 - K_F1_score: 0.3278
# Epoch 140/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.4235 - acc: 0.5991 - K_F1_score: 0.3263
# Epoch 141/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.4323 - acc: 0.5991 - K_F1_score: 0.3298
# Epoch 142/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.4478 - acc: 0.5991 - K_F1_score: 0.3301
# Epoch 143/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.4043 - acc: 0.5991 - K_F1_score: 0.3296
# Epoch 144/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.3935 - acc: 0.5991 - K_F1_score: 0.3303
# Epoch 145/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.3999 - acc: 0.5991 - K_F1_score: 0.3304
# Epoch 146/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.3589 - acc: 0.5991 - K_F1_score: 0.3289
# Epoch 147/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.3365 - acc: 0.5991 - K_F1_score: 0.3295
# Epoch 148/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.3223 - acc: 0.5991 - K_F1_score: 0.3311
# Epoch 149/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.3062 - acc: 0.5991 - K_F1_score: 0.3296: 0s - loss: 1.3154 - acc: 0.6146 - K_
# Epoch 150/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.3185 - acc: 0.5991 - K_F1_score: 0.3300
# Epoch 151/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.3033 - acc: 0.5991 - K_F1_score: 0.3306
# Epoch 152/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.2933 - acc: 0.5991 - K_F1_score: 0.3302
# Epoch 153/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.2782 - acc: 0.5991 - K_F1_score: 0.3304
# Epoch 154/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.2712 - acc: 0.5991 - K_F1_score: 0.3292
# Epoch 155/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.2353 - acc: 0.5991 - K_F1_score: 0.3315
# Epoch 156/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.2449 - acc: 0.5991 - K_F1_score: 0.3287
# Epoch 157/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.2138 - acc: 0.5991 - K_F1_score: 0.3295
# Epoch 158/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.2027 - acc: 0.5991 - K_F1_score: 0.3289
# Epoch 159/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.1839 - acc: 0.5991 - K_F1_score: 0.3318
# Epoch 160/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.1837 - acc: 0.5991 - K_F1_score: 0.3281
# Epoch 161/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.1739 - acc: 0.5991 - K_F1_score: 0.3302
# Epoch 162/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.1740 - acc: 0.5991 - K_F1_score: 0.3282
# Epoch 163/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.1436 - acc: 0.5991 - K_F1_score: 0.3294
# Epoch 164/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.1357 - acc: 0.5991 - K_F1_score: 0.3287
# Epoch 165/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.1277 - acc: 0.5991 - K_F1_score: 0.3298
# Epoch 166/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.1277 - acc: 0.5991 - K_F1_score: 0.3301
# Epoch 167/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.1221 - acc: 0.5991 - K_F1_score: 0.3296
# Epoch 168/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.1063 - acc: 0.5991 - K_F1_score: 0.3296
# Epoch 169/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.1082 - acc: 0.5991 - K_F1_score: 0.3292
# Epoch 170/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.0826 - acc: 0.5991 - K_F1_score: 0.3311
# Epoch 171/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.0815 - acc: 0.5991 - K_F1_score: 0.3314
# Epoch 172/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.0564 - acc: 0.5991 - K_F1_score: 0.3280
# Epoch 173/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.0643 - acc: 0.5991 - K_F1_score: 0.3301
# Epoch 174/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.0473 - acc: 0.5991 - K_F1_score: 0.3299
# Epoch 175/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.0416 - acc: 0.5991 - K_F1_score: 0.3285
# Epoch 176/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.0369 - acc: 0.5991 - K_F1_score: 0.3316
# Epoch 177/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.0288 - acc: 0.5991 - K_F1_score: 0.3301
# Epoch 178/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.0211 - acc: 0.5991 - K_F1_score: 0.3314
# Epoch 179/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.0248 - acc: 0.5991 - K_F1_score: 0.3301
# Epoch 180/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.0079 - acc: 0.5991 - K_F1_score: 0.3317
# Epoch 181/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.0015 - acc: 0.5991 - K_F1_score: 0.3284: 0s - loss: 0.9452 - acc: 0.697
# Epoch 182/256
# 691/691 [==============================] - 1s 1ms/step - loss: 1.0009 - acc: 0.5991 - K_F1_score: 0.3296
# Epoch 183/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.9901 - acc: 0.5991 - K_F1_score: 0.3306
# Epoch 184/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.9921 - acc: 0.5991 - K_F1_score: 0.3306
# Epoch 185/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.9833 - acc: 0.5991 - K_F1_score: 0.3296
# Epoch 186/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.9951 - acc: 0.5991 - K_F1_score: 0.3311
# Epoch 187/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.9940 - acc: 0.5991 - K_F1_score: 0.3290
# Epoch 188/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.9748 - acc: 0.5991 - K_F1_score: 0.3289
# Epoch 189/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.9720 - acc: 0.5991 - K_F1_score: 0.3281
# Epoch 190/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.9632 - acc: 0.5991 - K_F1_score: 0.3300
# Epoch 191/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.9634 - acc: 0.5991 - K_F1_score: 0.3269
# Epoch 192/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.9519 - acc: 0.5991 - K_F1_score: 0.3305
# Epoch 193/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.9500 - acc: 0.5991 - K_F1_score: 0.3276
# Epoch 194/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.9468 - acc: 0.5991 - K_F1_score: 0.3307
# Epoch 195/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.9379 - acc: 0.5991 - K_F1_score: 0.3296
# Epoch 196/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.9238 - acc: 0.5991 - K_F1_score: 0.3300
# Epoch 197/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.9215 - acc: 0.5991 - K_F1_score: 0.3293
# Epoch 198/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.9169 - acc: 0.5991 - K_F1_score: 0.3305
# Epoch 199/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.9181 - acc: 0.5991 - K_F1_score: 0.3293
# Epoch 200/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.9135 - acc: 0.5991 - K_F1_score: 0.3311
# Epoch 201/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8987 - acc: 0.5991 - K_F1_score: 0.3305
# Epoch 202/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8972 - acc: 0.5991 - K_F1_score: 0.3304
# Epoch 203/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8900 - acc: 0.5991 - K_F1_score: 0.3301: 0s - loss: 0.8871 - acc: 0.6250 - K_F1_s
# Epoch 204/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8884 - acc: 0.5991 - K_F1_score: 0.3289
# Epoch 205/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8876 - acc: 0.5991 - K_F1_score: 0.3291
# Epoch 206/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8824 - acc: 0.5991 - K_F1_score: 0.3281
# Epoch 207/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8753 - acc: 0.5991 - K_F1_score: 0.3315
# Epoch 208/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8734 - acc: 0.5991 - K_F1_score: 0.3313
# Epoch 209/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8688 - acc: 0.5991 - K_F1_score: 0.3287
# Epoch 210/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8665 - acc: 0.5991 - K_F1_score: 0.3297
# Epoch 211/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8588 - acc: 0.5991 - K_F1_score: 0.3290
# Epoch 212/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8527 - acc: 0.5991 - K_F1_score: 0.3294
# Epoch 213/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8604 - acc: 0.5991 - K_F1_score: 0.3314
# Epoch 214/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8447 - acc: 0.5991 - K_F1_score: 0.3321
# Epoch 215/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8480 - acc: 0.5991 - K_F1_score: 0.3311
# Epoch 216/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8439 - acc: 0.5991 - K_F1_score: 0.3311
# Epoch 217/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8403 - acc: 0.5991 - K_F1_score: 0.3296
# Epoch 218/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8368 - acc: 0.5991 - K_F1_score: 0.3275
# Epoch 219/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8330 - acc: 0.5991 - K_F1_score: 0.3299
# Epoch 220/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8344 - acc: 0.5991 - K_F1_score: 0.3320
# Epoch 221/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8356 - acc: 0.5991 - K_F1_score: 0.3307
# Epoch 222/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8198 - acc: 0.5991 - K_F1_score: 0.3310
# Epoch 223/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8187 - acc: 0.5991 - K_F1_score: 0.3285
# Epoch 224/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8167 - acc: 0.5991 - K_F1_score: 0.3312
# Epoch 225/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8142 - acc: 0.5991 - K_F1_score: 0.3319
# Epoch 226/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8153 - acc: 0.5991 - K_F1_score: 0.3309
# Epoch 227/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8159 - acc: 0.5991 - K_F1_score: 0.3311
# Epoch 228/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8031 - acc: 0.5991 - K_F1_score: 0.3294
# Epoch 229/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8071 - acc: 0.5991 - K_F1_score: 0.3316
# Epoch 230/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.7965 - acc: 0.5991 - K_F1_score: 0.3305
# Epoch 231/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.8012 - acc: 0.5991 - K_F1_score: 0.3314
# Epoch 232/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.7922 - acc: 0.5991 - K_F1_score: 0.3291
# Epoch 233/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.7906 - acc: 0.5991 - K_F1_score: 0.3296
# Epoch 234/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.7904 - acc: 0.5991 - K_F1_score: 0.3299
# Epoch 235/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.7876 - acc: 0.5991 - K_F1_score: 0.3315
# Epoch 236/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.7902 - acc: 0.5991 - K_F1_score: 0.3307
# Epoch 237/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.7829 - acc: 0.5991 - K_F1_score: 0.3310
# Epoch 238/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.7822 - acc: 0.5991 - K_F1_score: 0.3296
# Epoch 239/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.7798 - acc: 0.5991 - K_F1_score: 0.3306
# Epoch 240/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.7851 - acc: 0.5991 - K_F1_score: 0.3305
# Epoch 241/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.7762 - acc: 0.5991 - K_F1_score: 0.3307
# Epoch 242/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.7708 - acc: 0.5991 - K_F1_score: 0.3308
# Epoch 243/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.7719 - acc: 0.5991 - K_F1_score: 0.3278
# Epoch 244/256
# 691/691 [==============================] - 1s 2ms/step - loss: 0.7707 - acc: 0.5991 - K_F1_score: 0.3288
# Epoch 245/256
# 691/691 [==============================] - 1s 2ms/step - loss: 0.7679 - acc: 0.5991 - K_F1_score: 0.3324
# Epoch 246/256
# 691/691 [==============================] - 1s 2ms/step - loss: 0.7664 - acc: 0.5991 - K_F1_score: 0.3306
# Epoch 247/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.7620 - acc: 0.5991 - K_F1_score: 0.3304
# Epoch 248/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.7675 - acc: 0.5991 - K_F1_score: 0.3289: 0s - loss: 0.7502 - acc: 0.6339 -
# Epoch 249/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.7637 - acc: 0.5991 - K_F1_score: 0.3300: 0s - loss: 0.7714 - acc: 0.5563 -
# Epoch 250/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.7579 - acc: 0.5991 - K_F1_score: 0.3303
# Epoch 251/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.7582 - acc: 0.5991 - K_F1_score: 0.3305
# Epoch 252/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.7556 - acc: 0.5991 - K_F1_score: 0.3317
# Epoch 253/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.7543 - acc: 0.5991 - K_F1_score: 0.3286
# Epoch 254/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.7513 - acc: 0.5991 - K_F1_score: 0.3296
# Epoch 255/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.7526 - acc: 0.5991 - K_F1_score: 0.3299
# Epoch 256/256
# 691/691 [==============================] - 1s 1ms/step - loss: 0.7481 - acc: 0.5991 - K_F1_score: 0.3297

# %%
train_pred = test_model.predict(x = X_Train)
cv_pred = test_model.predict(x = X_CV)

train_hat = normalize_predictions(train_pred)
cv_hat = normalize_predictions(cv_pred)

show_acc(Y_Train, train_hat)
show_acc(Y_CV, cv_hat)
# Out:
# C:\Users\Gurtrude\Python_notebooks\Titanic\Titanic_Import.py:295: RuntimeWarning: invalid value encountered in double_scalars
#   prec = true_pos / (true_pos + false_pos)
# Accuracy =  59.913169319826345
# F1 Score =  nan
#
# Confusion Matrix
#        Labels  Actual True  Actual False
# 0   Pred True          0.0           0.0
# 1  Pred False        277.0         414.0
# Accuracy =  67.5
# F1 Score =  nan
#
# Confusion Matrix
#        Labels  Actual True  Actual False
# 0   Pred True          0.0           0.0
# 1  Pred False         65.0         135.0

# %% [markdown]
# So that didn't work.  I guess there's a good reason this type of architecture is not used.
#
# It's worth trying fully connected blocks, for completeness sake (as well as practice implementing this type of architecture, as while it may not be suited for this task, it works very well for convolutional networks).

# %%
def ResBlock_v2(X, layers, units, act_reg = None, ker_reg = None):
    #Define layer dictionary
    X_Layer = {}
    
    #Single Layer to reduce dimensionality
    X = Dense(units, activation='relu', activity_regularizer = act_reg, kernel_regularizer = ker_reg)(X)

    #Snapshot first layer to skip to end
    X_Layer[0] = X
    
    for i in range(layers):
        X = Dense(units, activation='relu', activity_regularizer = act_reg, kernel_regularizer = ker_reg)(X)
        X_Layer[i + 1] = X
        
        
        for j in range(i):
            X = Add()([X, X_Layer[j]])
                       
        X = Activation('relu')(X)

    return X

# %%
def Build_Resnet_v2(input_shape, layers, act_reg = None, ker_reg = None):
    X_input = Input(input_shape)
    
    num_layers = len(layers)
    
    for i in range(num_layers):
        if i == 0 :
            X = ResBlock_v2(X_input, res_layers[i][1], res_layers[i][0], act_reg = act_reg, ker_reg = ker_reg)
        else :
            X = ResBlock_v2(X, res_layers[i][1], res_layers[i][0], act_reg = act_reg, ker_reg = ker_reg)
   
    #Build output layer
    X = Dense(1, activation='sigmoid')(X)
    
    model = Model(inputs = X_input, outputs = X, name='Residual_model')
    
    return model

# %%
test_model = Build_Resnet_v2((X_Train.shape[1], ), res_layers, regularizers.l2(0.01), None)
test_model.compile(optimizer = "Adam", loss = "binary_crossentropy", metrics = ["accuracy", K_F1_score])
test_model.fit(x = X_Train, y = Y_Train, epochs = 256, verbose = 1)
# Out:
# Epoch 1/256
# 691/691 [==============================] - 2s 3ms/step - loss: 69.4258 - acc: 0.4660 - K_F1_score: 0.3518
# Epoch 2/256
# 691/691 [==============================] - 1s 810us/step - loss: 7.3313 - acc: 0.4573 - K_F1_score: 0.4089
# Epoch 3/256
# 691/691 [==============================] - 1s 796us/step - loss: 5.8021 - acc: 0.6064 - K_F1_score: 0.3627
# Epoch 4/256
# 691/691 [==============================] - 1s 781us/step - loss: 5.3147 - acc: 0.5991 - K_F1_score: 0.3550
# Epoch 5/256
# 691/691 [==============================] - 1s 796us/step - loss: 4.9477 - acc: 0.5991 - K_F1_score: 0.3570
# Epoch 6/256
# 691/691 [==============================] - 1s 796us/step - loss: 4.6436 - acc: 0.5991 - K_F1_score: 0.3558
# Epoch 7/256
# 691/691 [==============================] - 1s 810us/step - loss: 4.3802 - acc: 0.5991 - K_F1_score: 0.3535
# Epoch 8/256
# 691/691 [==============================] - 1s 781us/step - loss: 4.1380 - acc: 0.5991 - K_F1_score: 0.3508
# Epoch 9/256
# 691/691 [==============================] - 1s 796us/step - loss: 3.9421 - acc: 0.5991 - K_F1_score: 0.3528
# Epoch 10/256
# 691/691 [==============================] - 1s 796us/step - loss: 3.7356 - acc: 0.5991 - K_F1_score: 0.3509
# Epoch 11/256
# 691/691 [==============================] - 1s 796us/step - loss: 3.5717 - acc: 0.5991 - K_F1_score: 0.3491
# Epoch 12/256
# 691/691 [==============================] - 1s 810us/step - loss: 3.4407 - acc: 0.5991 - K_F1_score: 0.3473
# Epoch 13/256
# 691/691 [==============================] - 1s 796us/step - loss: 3.3039 - acc: 0.5991 - K_F1_score: 0.3499
# Epoch 14/256
# 691/691 [==============================] - 1s 781us/step - loss: 3.1797 - acc: 0.5991 - K_F1_score: 0.3460
# Epoch 15/256
# 691/691 [==============================] - 1s 781us/step - loss: 3.0607 - acc: 0.5991 - K_F1_score: 0.3463
# Epoch 16/256
# 691/691 [==============================] - 1s 796us/step - loss: 2.9573 - acc: 0.5991 - K_F1_score: 0.3449
# Epoch 17/256
# 691/691 [==============================] - 1s 810us/step - loss: 2.8528 - acc: 0.5991 - K_F1_score: 0.3464
# Epoch 18/256
# 691/691 [==============================] - 1s 781us/step - loss: 2.7590 - acc: 0.5991 - K_F1_score: 0.3447
# Epoch 19/256
# 691/691 [==============================] - 1s 810us/step - loss: 2.6695 - acc: 0.5991 - K_F1_score: 0.3437
# Epoch 20/256
# 691/691 [==============================] - 1s 825us/step - loss: 2.5773 - acc: 0.5991 - K_F1_score: 0.3434
# Epoch 21/256
# 691/691 [==============================] - 1s 825us/step - loss: 2.5082 - acc: 0.5991 - K_F1_score: 0.3437
# Epoch 22/256
# 691/691 [==============================] - 1s 781us/step - loss: 2.4350 - acc: 0.5991 - K_F1_score: 0.3429
# Epoch 23/256
# 691/691 [==============================] - 1s 854us/step - loss: 2.3627 - acc: 0.5991 - K_F1_score: 0.3425
# Epoch 24/256
# 691/691 [==============================] - 1s 839us/step - loss: 2.2941 - acc: 0.5991 - K_F1_score: 0.3412
# Epoch 25/256
# 691/691 [==============================] - 1s 781us/step - loss: 2.2356 - acc: 0.5991 - K_F1_score: 0.3411
# Epoch 26/256
# 691/691 [==============================] - 1s 781us/step - loss: 2.1712 - acc: 0.5991 - K_F1_score: 0.3388
# Epoch 27/256
# 691/691 [==============================] - 1s 781us/step - loss: 2.1237 - acc: 0.5991 - K_F1_score: 0.3405
# Epoch 28/256
# 691/691 [==============================] - 1s 825us/step - loss: 2.0669 - acc: 0.5991 - K_F1_score: 0.3369
# Epoch 29/256
# 691/691 [==============================] - 1s 796us/step - loss: 2.0140 - acc: 0.5991 - K_F1_score: 0.3387
# Epoch 30/256
# 691/691 [==============================] - 1s 781us/step - loss: 1.9629 - acc: 0.5991 - K_F1_score: 0.3403
# Epoch 31/256
# 691/691 [==============================] - 1s 796us/step - loss: 1.9202 - acc: 0.5991 - K_F1_score: 0.3375
# Epoch 32/256
# 691/691 [==============================] - 1s 796us/step - loss: 1.8746 - acc: 0.5991 - K_F1_score: 0.3355
# Epoch 33/256
# 691/691 [==============================] - 1s 781us/step - loss: 1.8363 - acc: 0.5991 - K_F1_score: 0.3371
# Epoch 34/256
# 691/691 [==============================] - 1s 796us/step - loss: 1.7926 - acc: 0.5991 - K_F1_score: 0.3365
# Epoch 35/256
# 691/691 [==============================] - 1s 796us/step - loss: 1.7506 - acc: 0.5991 - K_F1_score: 0.3360
# Epoch 36/256
# 691/691 [==============================] - 1s 796us/step - loss: 1.7175 - acc: 0.5991 - K_F1_score: 0.3347
# Epoch 37/256
# 691/691 [==============================] - 1s 839us/step - loss: 1.6811 - acc: 0.5991 - K_F1_score: 0.3360
# Epoch 38/256
# 691/691 [==============================] - 1s 796us/step - loss: 1.6463 - acc: 0.5991 - K_F1_score: 0.3343
# Epoch 39/256
# 691/691 [==============================] - 1s 796us/step - loss: 1.6128 - acc: 0.5991 - K_F1_score: 0.3341
# Epoch 40/256
# 691/691 [==============================] - 1s 796us/step - loss: 1.5785 - acc: 0.5991 - K_F1_score: 0.3341
# Epoch 41/256
# 691/691 [==============================] - 1s 810us/step - loss: 1.5458 - acc: 0.5991 - K_F1_score: 0.3345
# Epoch 42/256
# 691/691 [==============================] - 1s 810us/step - loss: 1.5147 - acc: 0.5991 - K_F1_score: 0.3349
# Epoch 43/256
# 691/691 [==============================] - 1s 781us/step - loss: 1.4875 - acc: 0.5991 - K_F1_score: 0.3341
# Epoch 44/256
# 691/691 [==============================] - 1s 796us/step - loss: 1.4546 - acc: 0.5991 - K_F1_score: 0.3337
# Epoch 45/256
# 691/691 [==============================] - 1s 796us/step - loss: 1.4318 - acc: 0.5991 - K_F1_score: 0.3340
# Epoch 46/256
# 691/691 [==============================] - 1s 810us/step - loss: 1.4071 - acc: 0.5991 - K_F1_score: 0.3342
# Epoch 47/256
# 691/691 [==============================] - 1s 781us/step - loss: 1.3805 - acc: 0.5991 - K_F1_score: 0.3346
# Epoch 48/256
# 691/691 [==============================] - 1s 781us/step - loss: 1.3540 - acc: 0.5991 - K_F1_score: 0.3301
# Epoch 49/256
# 691/691 [==============================] - 1s 825us/step - loss: 1.3319 - acc: 0.5991 - K_F1_score: 0.3340
# Epoch 50/256
# 691/691 [==============================] - 1s 781us/step - loss: 1.3090 - acc: 0.5991 - K_F1_score: 0.3340
# Epoch 51/256
# 691/691 [==============================] - 1s 796us/step - loss: 1.2867 - acc: 0.5991 - K_F1_score: 0.3329
# Epoch 52/256
# 691/691 [==============================] - 1s 897us/step - loss: 1.2635 - acc: 0.5991 - K_F1_score: 0.3324
# Epoch 53/256
# 691/691 [==============================] - 1s 868us/step - loss: 1.2468 - acc: 0.5991 - K_F1_score: 0.3329
# Epoch 54/256
# 691/691 [==============================] - 1s 839us/step - loss: 1.2261 - acc: 0.5991 - K_F1_score: 0.3326
# Epoch 55/256
# 691/691 [==============================] - 1s 796us/step - loss: 1.2068 - acc: 0.5991 - K_F1_score: 0.3327
# Epoch 56/256
# 691/691 [==============================] - 1s 781us/step - loss: 1.1853 - acc: 0.5991 - K_F1_score: 0.3331
# Epoch 57/256
# 691/691 [==============================] - 1s 781us/step - loss: 1.1691 - acc: 0.5991 - K_F1_score: 0.3340
# Epoch 58/256
# 691/691 [==============================] - 1s 825us/step - loss: 1.1501 - acc: 0.5991 - K_F1_score: 0.3324
# Epoch 59/256
# 691/691 [==============================] - 1s 810us/step - loss: 1.1321 - acc: 0.5991 - K_F1_score: 0.3324
# Epoch 60/256
# 691/691 [==============================] - 1s 781us/step - loss: 1.1185 - acc: 0.5991 - K_F1_score: 0.3324
# Epoch 61/256
# 691/691 [==============================] - 1s 825us/step - loss: 1.1010 - acc: 0.5991 - K_F1_score: 0.3322
# Epoch 62/256
# 691/691 [==============================] - 1s 810us/step - loss: 1.0867 - acc: 0.5991 - K_F1_score: 0.3328
# Epoch 63/256
# 691/691 [==============================] - 1s 796us/step - loss: 1.0685 - acc: 0.5991 - K_F1_score: 0.3310
# Epoch 64/256
# 691/691 [==============================] - 1s 810us/step - loss: 1.0586 - acc: 0.5991 - K_F1_score: 0.3336
# Epoch 65/256
# 691/691 [==============================] - 1s 825us/step - loss: 1.0449 - acc: 0.5991 - K_F1_score: 0.3312
# Epoch 66/256
# 691/691 [==============================] - 1s 854us/step - loss: 1.0322 - acc: 0.5991 - K_F1_score: 0.3300
# Epoch 67/256
# 691/691 [==============================] - 1s 810us/step - loss: 1.0198 - acc: 0.5991 - K_F1_score: 0.3324
# Epoch 68/256
# 691/691 [==============================] - 1s 868us/step - loss: 1.0077 - acc: 0.5991 - K_F1_score: 0.3328
# Epoch 69/256
# 691/691 [==============================] - 1s 781us/step - loss: 0.9937 - acc: 0.5991 - K_F1_score: 0.3321
# Epoch 70/256
# 691/691 [==============================] - 1s 781us/step - loss: 0.9849 - acc: 0.5991 - K_F1_score: 0.3324
# Epoch 71/256
# 691/691 [==============================] - 1s 810us/step - loss: 0.9712 - acc: 0.5991 - K_F1_score: 0.3301
# Epoch 72/256
# 691/691 [==============================] - 1s 854us/step - loss: 0.9630 - acc: 0.5991 - K_F1_score: 0.3279
# Epoch 73/256
# 691/691 [==============================] - 1s 781us/step - loss: 0.9524 - acc: 0.5991 - K_F1_score: 0.3301
# Epoch 74/256
# 691/691 [==============================] - 1s 810us/step - loss: 0.9419 - acc: 0.5991 - K_F1_score: 0.3317
# Epoch 75/256
# 691/691 [==============================] - 1s 781us/step - loss: 0.9295 - acc: 0.5991 - K_F1_score: 0.3320
# Epoch 76/256
# 691/691 [==============================] - 1s 857us/step - loss: 0.9205 - acc: 0.5991 - K_F1_score: 0.3323
# Epoch 77/256
# 691/691 [==============================] - 1s 805us/step - loss: 0.9146 - acc: 0.5991 - K_F1_score: 0.3309
# Epoch 78/256
# 691/691 [==============================] - 1s 857us/step - loss: 0.9069 - acc: 0.5991 - K_F1_score: 0.3328
# Epoch 79/256
# 691/691 [==============================] - 1s 844us/step - loss: 0.8973 - acc: 0.5991 - K_F1_score: 0.3320
# Epoch 80/256
# 691/691 [==============================] - 1s 870us/step - loss: 0.8911 - acc: 0.5991 - K_F1_score: 0.3306
# Epoch 81/256
# 691/691 [==============================] - 1s 850us/step - loss: 0.8833 - acc: 0.5991 - K_F1_score: 0.3322
# Epoch 82/256
# 691/691 [==============================] - 1s 787us/step - loss: 0.8759 - acc: 0.5991 - K_F1_score: 0.3307
# Epoch 83/256
# 691/691 [==============================] - 1s 780us/step - loss: 0.8675 - acc: 0.5991 - K_F1_score: 0.3329
# Epoch 84/256
# 691/691 [==============================] - 1s 780us/step - loss: 0.8600 - acc: 0.5991 - K_F1_score: 0.3303
# Epoch 85/256
# 691/691 [==============================] - 1s 779us/step - loss: 0.8539 - acc: 0.5991 - K_F1_score: 0.3303
# Epoch 86/256
# 691/691 [==============================] - 1s 792us/step - loss: 0.8490 - acc: 0.5991 - K_F1_score: 0.3315
# Epoch 87/256
# 691/691 [==============================] - 1s 897us/step - loss: 0.8423 - acc: 0.5991 - K_F1_score: 0.3324
# Epoch 88/256
# 691/691 [==============================] - 1s 797us/step - loss: 0.8363 - acc: 0.5991 - K_F1_score: 0.3283
# Epoch 89/256
# 691/691 [==============================] - 1s 857us/step - loss: 0.8307 - acc: 0.5991 - K_F1_score: 0.3307
# Epoch 90/256
# 691/691 [==============================] - 1s 790us/step - loss: 0.8223 - acc: 0.5991 - K_F1_score: 0.3309
# Epoch 91/256
# 691/691 [==============================] - 1s 873us/step - loss: 0.8175 - acc: 0.5991 - K_F1_score: 0.3276
# Epoch 92/256
# 691/691 [==============================] - 1s 783us/step - loss: 0.8146 - acc: 0.5991 - K_F1_score: 0.3309
# Epoch 93/256
# 691/691 [==============================] - 1s 792us/step - loss: 0.8105 - acc: 0.5991 - K_F1_score: 0.3307
# Epoch 94/256
# 691/691 [==============================] - 1s 857us/step - loss: 0.8058 - acc: 0.5991 - K_F1_score: 0.3298
# Epoch 95/256
# 691/691 [==============================] - 1s 835us/step - loss: 0.8010 - acc: 0.5991 - K_F1_score: 0.3325
# Epoch 96/256
# 691/691 [==============================] - 1s 825us/step - loss: 0.7961 - acc: 0.5991 - K_F1_score: 0.3289
# Epoch 97/256
# 691/691 [==============================] - 1s 903us/step - loss: 0.7910 - acc: 0.5991 - K_F1_score: 0.3311
# Epoch 98/256
# 691/691 [==============================] - 1s 795us/step - loss: 0.7890 - acc: 0.5991 - K_F1_score: 0.3307
# Epoch 99/256
# 691/691 [==============================] - 1s 793us/step - loss: 0.7824 - acc: 0.5991 - K_F1_score: 0.3294
# Epoch 100/256
# 691/691 [==============================] - 1s 797us/step - loss: 0.7802 - acc: 0.5991 - K_F1_score: 0.3294
# Epoch 101/256
# 691/691 [==============================] - 1s 787us/step - loss: 0.7772 - acc: 0.5991 - K_F1_score: 0.3302
# Epoch 102/256
# 691/691 [==============================] - 1s 802us/step - loss: 0.7737 - acc: 0.5991 - K_F1_score: 0.3309
# Epoch 103/256
# 691/691 [==============================] - 1s 792us/step - loss: 0.7712 - acc: 0.5991 - K_F1_score: 0.3244
# Epoch 104/256
# 691/691 [==============================] - 1s 805us/step - loss: 0.7680 - acc: 0.5991 - K_F1_score: 0.3321
# Epoch 105/256
# 691/691 [==============================] - 1s 795us/step - loss: 0.7620 - acc: 0.5991 - K_F1_score: 0.3305
# Epoch 106/256
# 691/691 [==============================] - 1s 795us/step - loss: 0.7613 - acc: 0.5991 - K_F1_score: 0.3299
# Epoch 107/256
# 691/691 [==============================] - 1s 797us/step - loss: 0.7593 - acc: 0.5991 - K_F1_score: 0.3298
# Epoch 108/256
# 691/691 [==============================] - 1s 795us/step - loss: 0.7564 - acc: 0.5991 - K_F1_score: 0.3296
# Epoch 109/256
# 691/691 [==============================] - 1s 857us/step - loss: 0.7544 - acc: 0.5991 - K_F1_score: 0.3296
# Epoch 110/256
# 691/691 [==============================] - 1s 810us/step - loss: 0.7501 - acc: 0.5991 - K_F1_score: 0.3299
# Epoch 111/256
# 691/691 [==============================] - 1s 802us/step - loss: 0.7487 - acc: 0.5991 - K_F1_score: 0.3308
# Epoch 112/256
# 691/691 [==============================] - 1s 790us/step - loss: 0.7464 - acc: 0.5991 - K_F1_score: 0.3307
# Epoch 113/256
# 691/691 [==============================] - 1s 795us/step - loss: 0.7440 - acc: 0.5991 - K_F1_score: 0.3327
# Epoch 114/256
# 691/691 [==============================] - 1s 796us/step - loss: 0.7425 - acc: 0.5991 - K_F1_score: 0.3315
# Epoch 115/256
# 691/691 [==============================] - 1s 790us/step - loss: 0.7407 - acc: 0.5991 - K_F1_score: 0.3302
# Epoch 116/256
# 691/691 [==============================] - 1s 802us/step - loss: 0.7386 - acc: 0.5991 - K_F1_score: 0.3315
# Epoch 117/256
# 691/691 [==============================] - 1s 802us/step - loss: 0.7361 - acc: 0.5991 - K_F1_score: 0.3275
# Epoch 118/256
# 691/691 [==============================] - 1s 799us/step - loss: 0.7347 - acc: 0.5991 - K_F1_score: 0.3307
# Epoch 119/256
# 691/691 [==============================] - 1s 806us/step - loss: 0.7321 - acc: 0.5991 - K_F1_score: 0.3278
# Epoch 120/256
# 691/691 [==============================] - 1s 793us/step - loss: 0.7312 - acc: 0.5991 - K_F1_score: 0.3304
# Epoch 121/256
# 691/691 [==============================] - 1s 796us/step - loss: 0.7276 - acc: 0.5991 - K_F1_score: 0.3296
# Epoch 122/256
# 691/691 [==============================] - 1s 796us/step - loss: 0.7261 - acc: 0.5991 - K_F1_score: 0.3308
# Epoch 123/256
# 691/691 [==============================] - 1s 783us/step - loss: 0.7262 - acc: 0.5991 - K_F1_score: 0.3287
# Epoch 124/256
# 691/691 [==============================] - 1s 799us/step - loss: 0.7226 - acc: 0.5991 - K_F1_score: 0.3314
# Epoch 125/256
# 691/691 [==============================] - 1s 789us/step - loss: 0.7232 - acc: 0.5991 - K_F1_score: 0.3293
# Epoch 126/256
# 691/691 [==============================] - 1s 793us/step - loss: 0.7215 - acc: 0.5991 - K_F1_score: 0.3301
# Epoch 127/256
# 691/691 [==============================] - 1s 795us/step - loss: 0.7203 - acc: 0.5991 - K_F1_score: 0.3285
# Epoch 128/256
# 691/691 [==============================] - 1s 795us/step - loss: 0.7187 - acc: 0.5991 - K_F1_score: 0.3305
# Epoch 129/256
# 691/691 [==============================] - 1s 793us/step - loss: 0.7173 - acc: 0.5991 - K_F1_score: 0.3301
# Epoch 130/256
# 691/691 [==============================] - 1s 805us/step - loss: 0.7163 - acc: 0.5991 - K_F1_score: 0.3283
# Epoch 131/256
# 691/691 [==============================] - 1s 819us/step - loss: 0.7150 - acc: 0.5991 - K_F1_score: 0.3271
# Epoch 132/256
# 691/691 [==============================] - 1s 790us/step - loss: 0.7136 - acc: 0.5991 - K_F1_score: 0.3289
# Epoch 133/256
# 691/691 [==============================] - 1s 805us/step - loss: 0.7125 - acc: 0.5991 - K_F1_score: 0.3310
# Epoch 134/256
# 691/691 [==============================] - 1s 841us/step - loss: 0.7114 - acc: 0.5991 - K_F1_score: 0.3298
# Epoch 135/256
# 691/691 [==============================] - 1s 826us/step - loss: 0.7104 - acc: 0.5991 - K_F1_score: 0.3301
# Epoch 136/256
# 691/691 [==============================] - 1s 842us/step - loss: 0.7092 - acc: 0.5991 - K_F1_score: 0.3287
# Epoch 137/256
# 691/691 [==============================] - 1s 871us/step - loss: 0.7083 - acc: 0.5991 - K_F1_score: 0.3303
# Epoch 138/256
# 691/691 [==============================] - 1s 907us/step - loss: 0.7073 - acc: 0.5991 - K_F1_score: 0.3288
# Epoch 139/256
# 691/691 [==============================] - 1s 826us/step - loss: 0.7062 - acc: 0.5991 - K_F1_score: 0.3300
# Epoch 140/256
# 691/691 [==============================] - 1s 851us/step - loss: 0.7044 - acc: 0.5991 - K_F1_score: 0.3296
# Epoch 141/256
# 691/691 [==============================] - 1s 835us/step - loss: 0.7045 - acc: 0.5991 - K_F1_score: 0.3301
# Epoch 142/256
# 691/691 [==============================] - 1s 839us/step - loss: 0.7037 - acc: 0.5991 - K_F1_score: 0.3304
# Epoch 143/256
# 691/691 [==============================] - 1s 829us/step - loss: 0.7029 - acc: 0.5991 - K_F1_score: 0.3302
# Epoch 144/256
# 691/691 [==============================] - 1s 845us/step - loss: 0.7017 - acc: 0.5991 - K_F1_score: 0.3310
# Epoch 145/256
# 691/691 [==============================] - 1s 848us/step - loss: 0.7011 - acc: 0.5991 - K_F1_score: 0.3300
# Epoch 146/256
# 691/691 [==============================] - 1s 834us/step - loss: 0.7004 - acc: 0.5991 - K_F1_score: 0.3291
# Epoch 147/256
# 691/691 [==============================] - 1s 832us/step - loss: 0.6992 - acc: 0.5991 - K_F1_score: 0.3306
# Epoch 148/256
# 691/691 [==============================] - 1s 835us/step - loss: 0.6984 - acc: 0.5991 - K_F1_score: 0.3303
# Epoch 149/256
# 691/691 [==============================] - 1s 841us/step - loss: 0.6981 - acc: 0.5991 - K_F1_score: 0.3286
# Epoch 150/256
# 691/691 [==============================] - 1s 831us/step - loss: 0.6975 - acc: 0.5991 - K_F1_score: 0.3284
# Epoch 151/256
# 691/691 [==============================] - 1s 845us/step - loss: 0.6968 - acc: 0.5991 - K_F1_score: 0.3285
# Epoch 152/256
# 691/691 [==============================] - 1s 831us/step - loss: 0.6960 - acc: 0.5991 - K_F1_score: 0.3319
# Epoch 153/256
# 691/691 [==============================] - 1s 826us/step - loss: 0.6954 - acc: 0.5991 - K_F1_score: 0.3271
# Epoch 154/256
# 691/691 [==============================] - 1s 832us/step - loss: 0.6949 - acc: 0.5991 - K_F1_score: 0.3308
# Epoch 155/256
# 691/691 [==============================] - 1s 850us/step - loss: 0.6944 - acc: 0.5991 - K_F1_score: 0.3297
# Epoch 156/256
# 691/691 [==============================] - 1s 851us/step - loss: 0.6938 - acc: 0.5991 - K_F1_score: 0.3313
# Epoch 157/256
# 691/691 [==============================] - 1s 876us/step - loss: 0.6932 - acc: 0.5991 - K_F1_score: 0.3309
# Epoch 158/256
# 691/691 [==============================] - 1s 815us/step - loss: 0.6927 - acc: 0.5991 - K_F1_score: 0.3274
# Epoch 159/256
# 691/691 [==============================] - 1s 834us/step - loss: 0.6921 - acc: 0.5991 - K_F1_score: 0.3297
# Epoch 160/256
# 691/691 [==============================] - 1s 828us/step - loss: 0.6917 - acc: 0.5991 - K_F1_score: 0.3310
# Epoch 161/256
# 691/691 [==============================] - 1s 860us/step - loss: 0.6910 - acc: 0.5991 - K_F1_score: 0.3303
# Epoch 162/256
# 691/691 [==============================] - 1s 838us/step - loss: 0.6907 - acc: 0.5991 - K_F1_score: 0.3307
# Epoch 163/256
# 691/691 [==============================] - 1s 837us/step - loss: 0.6903 - acc: 0.5991 - K_F1_score: 0.3318
# Epoch 164/256
# 691/691 [==============================] - 1s 847us/step - loss: 0.6898 - acc: 0.5991 - K_F1_score: 0.3312
# Epoch 165/256
# 691/691 [==============================] - 1s 909us/step - loss: 0.6893 - acc: 0.5991 - K_F1_score: 0.3285
# Epoch 166/256
# 691/691 [==============================] - 1s 871us/step - loss: 0.6888 - acc: 0.5991 - K_F1_score: 0.3309
# Epoch 167/256
# 691/691 [==============================] - 1s 816us/step - loss: 0.6886 - acc: 0.5991 - K_F1_score: 0.3301
# Epoch 168/256
# 691/691 [==============================] - 1s 855us/step - loss: 0.6881 - acc: 0.5991 - K_F1_score: 0.3294
# Epoch 169/256
# 691/691 [==============================] - 1s 848us/step - loss: 0.6876 - acc: 0.5991 - K_F1_score: 0.3291
# Epoch 170/256
# 691/691 [==============================] - 1s 825us/step - loss: 0.6870 - acc: 0.5991 - K_F1_score: 0.3304
# Epoch 171/256
# 691/691 [==============================] - 1s 839us/step - loss: 0.6870 - acc: 0.5991 - K_F1_score: 0.3302
# Epoch 172/256
# 691/691 [==============================] - 1s 835us/step - loss: 0.6866 - acc: 0.5991 - K_F1_score: 0.3307
# Epoch 173/256
# 691/691 [==============================] - 1s 832us/step - loss: 0.6863 - acc: 0.5991 - K_F1_score: 0.3299
# Epoch 174/256
# 691/691 [==============================] - 1s 835us/step - loss: 0.6859 - acc: 0.5991 - K_F1_score: 0.3305
# Epoch 175/256
# 691/691 [==============================] - 1s 844us/step - loss: 0.6856 - acc: 0.5991 - K_F1_score: 0.3274
# Epoch 176/256
# 691/691 [==============================] - 1s 826us/step - loss: 0.6852 - acc: 0.5991 - K_F1_score: 0.3288
# Epoch 177/256
# 691/691 [==============================] - 1s 854us/step - loss: 0.6849 - acc: 0.5991 - K_F1_score: 0.3303
# Epoch 178/256
# 691/691 [==============================] - 1s 839us/step - loss: 0.6847 - acc: 0.5991 - K_F1_score: 0.3288
# Epoch 179/256
# 691/691 [==============================] - 1s 839us/step - loss: 0.6844 - acc: 0.5991 - K_F1_score: 0.3290
# Epoch 180/256
# 691/691 [==============================] - 1s 828us/step - loss: 0.6841 - acc: 0.5991 - K_F1_score: 0.3283
# Epoch 181/256
# 691/691 [==============================] - 1s 825us/step - loss: 0.6838 - acc: 0.5991 - K_F1_score: 0.3287
# Epoch 182/256
# 691/691 [==============================] - 1s 819us/step - loss: 0.6834 - acc: 0.5991 - K_F1_score: 0.3310
# Epoch 183/256
# 691/691 [==============================] - 1s 878us/step - loss: 0.6831 - acc: 0.5991 - K_F1_score: 0.3289
# Epoch 184/256
# 691/691 [==============================] - 1s 832us/step - loss: 0.6831 - acc: 0.5991 - K_F1_score: 0.3286
# Epoch 185/256
# 691/691 [==============================] - 1s 855us/step - loss: 0.6828 - acc: 0.5991 - K_F1_score: 0.3298
# Epoch 186/256
# 691/691 [==============================] - 1s 860us/step - loss: 0.6820 - acc: 0.5991 - K_F1_score: 0.3284
# Epoch 187/256
# 691/691 [==============================] - 1s 851us/step - loss: 0.6823 - acc: 0.5991 - K_F1_score: 0.3290
# Epoch 188/256
# 691/691 [==============================] - 1s 822us/step - loss: 0.6822 - acc: 0.5991 - K_F1_score: 0.3299
# Epoch 189/256
# 691/691 [==============================] - 1s 834us/step - loss: 0.6819 - acc: 0.5991 - K_F1_score: 0.3296
# Epoch 190/256
# 691/691 [==============================] - 1s 850us/step - loss: 0.6816 - acc: 0.5991 - K_F1_score: 0.3285
# Epoch 191/256
# 691/691 [==============================] - 1s 839us/step - loss: 0.6810 - acc: 0.5991 - K_F1_score: 0.3294
# Epoch 192/256
# 691/691 [==============================] - 1s 860us/step - loss: 0.6812 - acc: 0.5991 - K_F1_score: 0.3303
# Epoch 193/256
# 691/691 [==============================] - 1s 871us/step - loss: 0.6810 - acc: 0.5991 - K_F1_score: 0.3311
# Epoch 194/256
# 691/691 [==============================] - 1s 834us/step - loss: 0.6805 - acc: 0.5991 - K_F1_score: 0.3314
# Epoch 195/256
# 691/691 [==============================] - 1s 823us/step - loss: 0.6806 - acc: 0.5991 - K_F1_score: 0.3287
# Epoch 196/256
# 691/691 [==============================] - ETA: 0s - loss: 0.6815 - acc: 0.5967 - K_F1_score: 0.33 - 1s 839us/step - loss: 0.6804 - acc: 0.5991 - K_F1_score: 0.3311
# Epoch 197/256
# 691/691 [==============================] - 1s 826us/step - loss: 0.6803 - acc: 0.5991 - K_F1_score: 0.3298
# Epoch 198/256
# 691/691 [==============================] - 1s 837us/step - loss: 0.6801 - acc: 0.5991 - K_F1_score: 0.3288
# Epoch 199/256
# 691/691 [==============================] - 1s 845us/step - loss: 0.6799 - acc: 0.5991 - K_F1_score: 0.3291
# Epoch 200/256
# 691/691 [==============================] - 1s 854us/step - loss: 0.6797 - acc: 0.5991 - K_F1_score: 0.3314
# Epoch 201/256
# 691/691 [==============================] - 1s 835us/step - loss: 0.6796 - acc: 0.5991 - K_F1_score: 0.3303
# Epoch 202/256
# 691/691 [==============================] - 1s 821us/step - loss: 0.6795 - acc: 0.5991 - K_F1_score: 0.3282
# Epoch 203/256
# 691/691 [==============================] - 1s 832us/step - loss: 0.6793 - acc: 0.5991 - K_F1_score: 0.3286
# Epoch 204/256
# 691/691 [==============================] - 1s 831us/step - loss: 0.6791 - acc: 0.5991 - K_F1_score: 0.3292
# Epoch 205/256
# 691/691 [==============================] - 1s 837us/step - loss: 0.6790 - acc: 0.5991 - K_F1_score: 0.3312
# Epoch 206/256
# 691/691 [==============================] - 1s 861us/step - loss: 0.6788 - acc: 0.5991 - K_F1_score: 0.3309
# Epoch 207/256
# 691/691 [==============================] - 1s 831us/step - loss: 0.6787 - acc: 0.5991 - K_F1_score: 0.3293
# Epoch 208/256
# 691/691 [==============================] - 1s 821us/step - loss: 0.6785 - acc: 0.5991 - K_F1_score: 0.3286
# Epoch 209/256
# 691/691 [==============================] - 1s 834us/step - loss: 0.6782 - acc: 0.5991 - K_F1_score: 0.3304
# Epoch 210/256
# 691/691 [==============================] - 1s 838us/step - loss: 0.6783 - acc: 0.5991 - K_F1_score: 0.3308
# Epoch 211/256
# 691/691 [==============================] - 1s 842us/step - loss: 0.6780 - acc: 0.5991 - K_F1_score: 0.3305
# Epoch 212/256
# 691/691 [==============================] - 1s 829us/step - loss: 0.6781 - acc: 0.5991 - K_F1_score: 0.3297
# Epoch 213/256
# 691/691 [==============================] - 1s 832us/step - loss: 0.6780 - acc: 0.5991 - K_F1_score: 0.3298
# Epoch 214/256
# 691/691 [==============================] - 1s 828us/step - loss: 0.6778 - acc: 0.5991 - K_F1_score: 0.3296
# Epoch 215/256
# 691/691 [==============================] - 1s 847us/step - loss: 0.6777 - acc: 0.5991 - K_F1_score: 0.3294
# Epoch 216/256
# 691/691 [==============================] - 1s 828us/step - loss: 0.6776 - acc: 0.5991 - K_F1_score: 0.3305
# Epoch 217/256
# 691/691 [==============================] - 1s 847us/step - loss: 0.6775 - acc: 0.5991 - K_F1_score: 0.3288
# Epoch 218/256
# 691/691 [==============================] - 1s 839us/step - loss: 0.6774 - acc: 0.5991 - K_F1_score: 0.3271
# Epoch 219/256
# 691/691 [==============================] - 1s 839us/step - loss: 0.6773 - acc: 0.5991 - K_F1_score: 0.3299
# Epoch 220/256
# 691/691 [==============================] - 1s 913us/step - loss: 0.6772 - acc: 0.5991 - K_F1_score: 0.3313
# Epoch 221/256
# 691/691 [==============================] - 1s 865us/step - loss: 0.6768 - acc: 0.5991 - K_F1_score: 0.3306
# Epoch 222/256
# 691/691 [==============================] - 1s 842us/step - loss: 0.6770 - acc: 0.5991 - K_F1_score: 0.3320
# Epoch 223/256
# 691/691 [==============================] - 1s 848us/step - loss: 0.6769 - acc: 0.5991 - K_F1_score: 0.3320
# Epoch 224/256
# 691/691 [==============================] - 1s 851us/step - loss: 0.6768 - acc: 0.5991 - K_F1_score: 0.3286
# Epoch 225/256
# 691/691 [==============================] - 1s 835us/step - loss: 0.6767 - acc: 0.5991 - K_F1_score: 0.3318
# Epoch 226/256
# 691/691 [==============================] - ETA: 0s - loss: 0.6778 - acc: 0.5952 - K_F1_score: 0.33 - 1s 831us/step - loss: 0.6764 - acc: 0.5991 - K_F1_score: 0.3309
# Epoch 227/256
# 691/691 [==============================] - 1s 834us/step - loss: 0.6763 - acc: 0.5991 - K_F1_score: 0.3301
# Epoch 228/256
# 691/691 [==============================] - 1s 854us/step - loss: 0.6763 - acc: 0.5991 - K_F1_score: 0.3321
# Epoch 229/256
# 691/691 [==============================] - 1s 847us/step - loss: 0.6764 - acc: 0.5991 - K_F1_score: 0.3294
# Epoch 230/256
# 691/691 [==============================] - 1s 865us/step - loss: 0.6764 - acc: 0.5991 - K_F1_score: 0.3304
# Epoch 231/256
# 691/691 [==============================] - 1s 845us/step - loss: 0.6762 - acc: 0.5991 - K_F1_score: 0.3303
# Epoch 232/256
# 691/691 [==============================] - 1s 838us/step - loss: 0.6762 - acc: 0.5991 - K_F1_score: 0.3284
# Epoch 233/256
# 691/691 [==============================] - 1s 835us/step - loss: 0.6761 - acc: 0.5991 - K_F1_score: 0.3288
# Epoch 234/256
# 691/691 [==============================] - 1s 826us/step - loss: 0.6760 - acc: 0.5991 - K_F1_score: 0.3308
# Epoch 235/256
# 691/691 [==============================] - 1s 841us/step - loss: 0.6760 - acc: 0.5991 - K_F1_score: 0.3309
# Epoch 236/256
# 691/691 [==============================] - 1s 839us/step - loss: 0.6759 - acc: 0.5991 - K_F1_score: 0.3314
# Epoch 237/256
# 691/691 [==============================] - 1s 847us/step - loss: 0.6759 - acc: 0.5991 - K_F1_score: 0.3281
# Epoch 238/256
# 691/691 [==============================] - 1s 831us/step - loss: 0.6758 - acc: 0.5991 - K_F1_score: 0.3300
# Epoch 239/256
# 691/691 [==============================] - 1s 848us/step - loss: 0.6758 - acc: 0.5991 - K_F1_score: 0.3299
# Epoch 240/256
# 691/691 [==============================] - 1s 825us/step - loss: 0.6757 - acc: 0.5991 - K_F1_score: 0.3290
# Epoch 241/256
# 691/691 [==============================] - 1s 841us/step - loss: 0.6756 - acc: 0.5991 - K_F1_score: 0.3300
# Epoch 242/256
# 691/691 [==============================] - 1s 852us/step - loss: 0.6756 - acc: 0.5991 - K_F1_score: 0.3316
# Epoch 243/256
# 691/691 [==============================] - 1s 815us/step - loss: 0.6755 - acc: 0.5991 - K_F1_score: 0.3312
# Epoch 244/256
# 691/691 [==============================] - 1s 848us/step - loss: 0.6754 - acc: 0.5991 - K_F1_score: 0.3304
# Epoch 245/256
# 691/691 [==============================] - 1s 867us/step - loss: 0.6754 - acc: 0.5991 - K_F1_score: 0.3322
# Epoch 246/256
# 691/691 [==============================] - 1s 839us/step - loss: 0.6752 - acc: 0.5991 - K_F1_score: 0.3294
# Epoch 247/256
# 691/691 [==============================] - 1s 873us/step - loss: 0.6753 - acc: 0.5991 - K_F1_score: 0.3303
# Epoch 248/256
# 691/691 [==============================] - 1s 886us/step - loss: 0.6753 - acc: 0.5991 - K_F1_score: 0.3294
# Epoch 249/256
# 691/691 [==============================] - 1s 854us/step - loss: 0.6751 - acc: 0.5991 - K_F1_score: 0.3285
# Epoch 250/256
# 691/691 [==============================] - 1s 822us/step - loss: 0.6752 - acc: 0.5991 - K_F1_score: 0.3309
# Epoch 251/256
# 691/691 [==============================] - 1s 839us/step - loss: 0.6750 - acc: 0.5991 - K_F1_score: 0.3301
# Epoch 252/256
# 691/691 [==============================] - 1s 847us/step - loss: 0.6751 - acc: 0.5991 - K_F1_score: 0.3285
# Epoch 253/256
# 691/691 [==============================] - 1s 855us/step - loss: 0.6749 - acc: 0.5991 - K_F1_score: 0.3298
# Epoch 254/256
# 691/691 [==============================] - 1s 851us/step - loss: 0.6750 - acc: 0.5991 - K_F1_score: 0.3300
# Epoch 255/256
# 691/691 [==============================] - 1s 835us/step - loss: 0.6748 - acc: 0.5991 - K_F1_score: 0.3261
# Epoch 256/256
# 691/691 [==============================] - 1s 838us/step - loss: 0.6749 - acc: 0.5991 - K_F1_score: 0.3285

# %%
train_pred = test_model.predict(x = X_Train)
cv_pred = test_model.predict(x = X_CV)

train_hat = normalize_predictions(train_pred)
cv_hat = normalize_predictions(cv_pred)

show_acc(Y_Train, train_hat)
show_acc(Y_CV, cv_hat)
# Out:
# Accuracy =  59.913169319826345
# F1 Score =  nan
#
# Confusion Matrix
#        Labels  Actual True  Actual False
# 0   Pred True          0.0           0.0
# 1  Pred False        277.0         414.0
# Accuracy =  67.5
# F1 Score =  nan
#
# Confusion Matrix
#        Labels  Actual True  Actual False
# 0   Pred True          0.0           0.0
# 1  Pred False         65.0         135.0
# C:\Users\Gurtrude\Python_notebooks\Titanic\Titanic_Import.py:295: RuntimeWarning: invalid value encountered in double_scalars
#   prec = true_pos / (true_pos + false_pos)

# %% [markdown]
# And thus this experiment was an unfortunate failure, however maybe there is a way to make it work in order to enable extremely deep conventional fully connected networks.  Either way I'm happy I tried it to at least see it for myself.  Perhaps more insight can be derived by delving into the weights and observing how the weights evolve over training periods, however that's a different project for a different day.
#
# No matter, the next thing to address in this notebook is a simple test to see how LightGBM works.
#
# ## LightGBM
#
# So with gradient boosting packages such as XGBoost (among others) being as popular as they are its worth having a look at the syntax to implement the one I decided to try out first - LightGBM.  Then to evaluate its performance in the context with other notebooks in this series.

# %%
import lightgbm as lgb

# %% [markdown]
# So the package was imported correctly, now to play around with the parameters.

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'binary',
    'num_leaves': 30,
    'learning_rate': 0.03,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 0
}

#boosting types available: gbdt (standard), rf (random forest),
#                          dart (dropout additive trees), goss (one sided sampling)


#Apparently lightGBM needs a different training dataset schema
lgb_train = lgb.Dataset(X_Train, Y_Train)
lgb_eval = lgb.Dataset(X_CV, Y_CV, reference=lgb_train)

# %%
testgbm = lgb.train(params,
                lgb_train,
                num_boost_round=500,
                valid_sets=lgb_eval,
                early_stopping_rounds=10)
# Out:
# [1]	valid_0's binary_logloss: 0.67999
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's binary_logloss: 0.66812
# [3]	valid_0's binary_logloss: 0.656368
# [4]	valid_0's binary_logloss: 0.644288
# [5]	valid_0's binary_logloss: 0.63363
# [6]	valid_0's binary_logloss: 0.622875
# [7]	valid_0's binary_logloss: 0.612415
# [8]	valid_0's binary_logloss: 0.602441
# [9]	valid_0's binary_logloss: 0.593052
# [10]	valid_0's binary_logloss: 0.584099
# [11]	valid_0's binary_logloss: 0.575881
# [12]	valid_0's binary_logloss: 0.568109
# [13]	valid_0's binary_logloss: 0.560739
# [14]	valid_0's binary_logloss: 0.553518
# [15]	valid_0's binary_logloss: 0.546957
# [16]	valid_0's binary_logloss: 0.538992
# [17]	valid_0's binary_logloss: 0.53232
# [18]	valid_0's binary_logloss: 0.524997
# [19]	valid_0's binary_logloss: 0.518535
# [20]	valid_0's binary_logloss: 0.512675
# [21]	valid_0's binary_logloss: 0.507524
# [22]	valid_0's binary_logloss: 0.502107
# [23]	valid_0's binary_logloss: 0.497146
# [24]	valid_0's binary_logloss: 0.492224
# [25]	valid_0's binary_logloss: 0.488143
# [26]	valid_0's binary_logloss: 0.483575
# [27]	valid_0's binary_logloss: 0.479717
# [28]	valid_0's binary_logloss: 0.475863
# [29]	valid_0's binary_logloss: 0.471934
# [30]	valid_0's binary_logloss: 0.468223
# [31]	valid_0's binary_logloss: 0.465134
# [32]	valid_0's binary_logloss: 0.462294
# [33]	valid_0's binary_logloss: 0.459468
# [34]	valid_0's binary_logloss: 0.456904
# [35]	valid_0's binary_logloss: 0.454711
# [36]	valid_0's binary_logloss: 0.452429
# [37]	valid_0's binary_logloss: 0.449546
# [38]	valid_0's binary_logloss: 0.446966
# [39]	valid_0's binary_logloss: 0.444241
# [40]	valid_0's binary_logloss: 0.441524
# [41]	valid_0's binary_logloss: 0.43924
# [42]	valid_0's binary_logloss: 0.436891
# [43]	valid_0's binary_logloss: 0.434566
# [44]	valid_0's binary_logloss: 0.432644
# [45]	valid_0's binary_logloss: 0.430521
# [46]	valid_0's binary_logloss: 0.428941
# [47]	valid_0's binary_logloss: 0.427423
# [48]	valid_0's binary_logloss: 0.426124
# [49]	valid_0's binary_logloss: 0.425021
# [50]	valid_0's binary_logloss: 0.423659
# [51]	valid_0's binary_logloss: 0.421625
# [52]	valid_0's binary_logloss: 0.420402
# [53]	valid_0's binary_logloss: 0.4191
# [54]	valid_0's binary_logloss: 0.417312
# [55]	valid_0's binary_logloss: 0.416018
# [56]	valid_0's binary_logloss: 0.416251
# [57]	valid_0's binary_logloss: 0.415836
# [58]	valid_0's binary_logloss: 0.414882
# [59]	valid_0's binary_logloss: 0.414341
# [60]	valid_0's binary_logloss: 0.414167
# [61]	valid_0's binary_logloss: 0.413216
# [62]	valid_0's binary_logloss: 0.411897
# [63]	valid_0's binary_logloss: 0.410724
# [64]	valid_0's binary_logloss: 0.410515
# [65]	valid_0's binary_logloss: 0.409392
# [66]	valid_0's binary_logloss: 0.40883
# [67]	valid_0's binary_logloss: 0.408325
# [68]	valid_0's binary_logloss: 0.408335
# [69]	valid_0's binary_logloss: 0.408367
# [70]	valid_0's binary_logloss: 0.407647
# [71]	valid_0's binary_logloss: 0.407133
# [72]	valid_0's binary_logloss: 0.407023
# [73]	valid_0's binary_logloss: 0.407019
# [74]	valid_0's binary_logloss: 0.407036
# [75]	valid_0's binary_logloss: 0.40682
# [76]	valid_0's binary_logloss: 0.407192
# [77]	valid_0's binary_logloss: 0.407614
# [78]	valid_0's binary_logloss: 0.40722
# [79]	valid_0's binary_logloss: 0.407654
# [80]	valid_0's binary_logloss: 0.408193
# [81]	valid_0's binary_logloss: 0.407727
# [82]	valid_0's binary_logloss: 0.407947
# [83]	valid_0's binary_logloss: 0.407603
# [84]	valid_0's binary_logloss: 0.407317
# [85]	valid_0's binary_logloss: 0.407096
# Early stopping, best iteration is:
# [75]	valid_0's binary_logloss: 0.40682

# %%
gbm_Train_pred = testgbm.predict(X_Train, num_iteration=testgbm.best_iteration)
gbm_CV_pred = testgbm.predict(X_CV, num_iteration=testgbm.best_iteration)

# %%
gbm_CV_pred.shape
# Out:
# (200,)

# %%
gbm_train_hat = normalize_predictions(gbm_Train_pred)
gbm_cv_hat = normalize_predictions(gbm_CV_pred)

show_acc(Y_Train, gbm_train_hat)
show_acc(Y_CV, gbm_cv_hat)
# Out:
# Accuracy =  86.97539797395079
# F1 Score =  0.8192771084337349
#
# Confusion Matrix
#        Labels  Actual True  Actual False
# 0   Pred True        204.0          27.0
# 1  Pred False         63.0         397.0
# Accuracy =  82.5
# F1 Score =  0.7482014388489209
#
# Confusion Matrix
#        Labels  Actual True  Actual False
# 0   Pred True         52.0          12.0
# 1  Pred False         23.0         113.0

# %% [markdown]
# ### Results
#
# So the above example of results is indicative of most average runs.
#
# Overall most configurations had 87-89% training accuracy and 82-84% cross validation accuracy.  Interestingly random forest was one of the worst performing models in contrast to what I saw with the sci-kit learn implementation.
#
# #### Positives
# * Trains INSANELY fast (at almost any number of iterations trained near instantly)
# * Automatic cross validation/early stopping for easy regularization
# * Pretty solid out of the box performance
# * Easy and simple to use out of the box (at least at first)
#
# #### Negatives
# * Will need to figure out some way to enforce generalization and will take some reading/trial and error
# * Definitely will need ensembling with other models
# * Will need a bit of reading to understand exactly what's going on "under the hood" to tune it correctly
# * Worse performance than some of the neural net models

# %% [markdown]
# This was a fairly short and simple notebook by comparison to some of the previous books, but it was a simple excersize of curiosity.
#
# The next thing I want to experiment with is Genetic Programming.  It seems like a very interesting programming paradigm and I expect to find use for it in the future, but in order to figure out how to use it the best way is to try it out.
